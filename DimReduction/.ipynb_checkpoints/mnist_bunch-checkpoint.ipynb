# %%
import gzip
import pickle
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.decomposition import NMF
from sklearn.decomposition import FastICA
from sklearn.metrics import mean_squared_error
import numpy as np
from scipy.linalg import svd
from tabulate import tabulate

from timeit import default_timer as timer

# %% [markdown]
# # 1. Reduciendo MNIST

# %%
f_pickle = "mnist_32.bnch"
f = gzip.open(f_pickle, mode='rb')
bnch = pickle.load(f)
f.close()

# %%
print(bnch.keys())
# Out:
# dict_keys(['DESCR', 'data', 'target', 'data_test', 'target_test'])

# %%
print(bnch['DESCR'])
# Out:
# MNIST data set from Lecun site: http://yann.lecun.com/exdb/mnist/

# %%
print(bnch['data'].shape)
# Out:
# (60000, 32, 32, 1)

# %%
print(bnch['target'].shape)
# Out:
# (60000,)

# %%
SAMPLE = 9
NFEAT = 40

# %%
# pick a sample to plot
sample = SAMPLE
image = bnch['data'][sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# ## PCA en MNIST

# %%
start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
print(data.shape)
data = np.array(data).reshape(N, M*M)
pca = PCA(n_components=NFEAT)
reduced_data = pca.fit_transform(data)
cov = pca.get_covariance()
recoverPCA = pca.inverse_transform(reduced_data)
recoverPCA = np.array(recoverPCA).reshape(N, M, M, 1)
print(cov.shape)
U, s, VT = svd(cov)
print(s[:NFEAT*2])
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# (60000, 32, 32, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dbe6c713e63e> in <module>
#       5 print(data.shape)
#       6 data = np.array(data).reshape(N, M*M)
# ----> 7 pca = PCA(n_components=NFEAT)
#       8 reduced_data = pca.fit_transform(data)
#       9 cov = pca.get_covariance()
#
# NameError: name 'NFEAT' is not defined

# %%
plt.yscale("log")
plt.plot((s[:100]*s[:100])/745)
# Repasar como coger cierto porcentaje de varianza según el nª de autovalores

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverPCA[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# ## NMF en MNIST

# %%
start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
model = NMF(n_components=NFEAT, init='random', random_state=0)
reduced_data = model.fit_transform(data)
recoverNMF = model.inverse_transform(reduced_data)
recoverNMF = np.array(recoverNMF).reshape(N, M, M, 1)
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# /home/man3/.local/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# Tiempo --> 93.87 s

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverNMF[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# ## ICA en MNIST

# %% [markdown]
# ### Arquitectura 1

# %%
## Produce imágenes bases estadísticamente independientes

start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
print(data.shape)
transformer = FastICA(n_components=40, random_state=0)
reduced_data = transformer.fit_transform(data)
recoverICA = transformer.inverse_transform(reduced_data)
print(recoverICA.shape)
recoverICA = np.array(recoverICA).reshape(N, M, M, 1)
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# (60000, 1024)
# (60000, 1024)
#
# Tiempo --> 9.55 s

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverICA[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# ### Arquitectura 2

# %%
## Encuentra una representación en la cual los coeficientes usados para
## codificar las imágenes(los pixeles) son estadísticamente independientes

start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
data = np.transpose(data)
print(data.shape)
transformer = FastICA(n_components=40, random_state=0)
reduced_data = transformer.fit_transform(data)
recoverICA2 = transformer.inverse_transform(reduced_data)
recoverICA2 = np.transpose(recoverICA2)
print(recoverICA2.shape)
recoverICA2 = np.array(recoverICA2).reshape(N, M, M, 1)
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# (1024, 60000)
# (60000, 1024)
#
# Tiempo --> 40.61 s

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverICA2[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# PRUEBA 1

# %%
start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
print(data.shape)
transformer = FastICA(n_components=40, random_state=0, algorithm='parallel')
reduced_data = transformer.fit_transform(data)
recoverICAP = transformer.inverse_transform(reduced_data)
print(recoverICAP.shape)
recoverICAP = np.array(recoverICAP).reshape(N, M, M, 1)
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# (60000, 1024)
# (60000, 1024)
#
# Tiempo --> 44.63 s

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverICAP[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# PRUEBA 2

# %%
start = timer()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
print(data.shape)
transformer = FastICA(n_components=40, random_state=0, algorithm='deflation', max_iter=10)
reduced_data = transformer.fit_transform(data)
recoverICAD = transformer.inverse_transform(reduced_data)
print(recoverICAD.shape)
recoverICAD = np.array(recoverICAD).reshape(N, M, M, 1)
end = timer()
print("\nTiempo --> %.2f" % (end - start) + " s")
# Out:
# (60000, 1024)
# (60000, 1024)
#
# Tiempo --> 157.68 s

# %%
# pick a sample to plot
sample = SAMPLE
image = recoverICAD[sample]

# plot the sample
fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()
print(bnch['target'][sample])
# Out:
# 4

# %% [markdown]
# # 2. Análisis en EOLO

# %%
## Leemos los datos del fichero y aplicamos transformaciones
f_pickle = "mnist_32.bnch"
f = gzip.open(f_pickle, mode='rb')
bnch = pickle.load(f)
f.close()
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
target = bnch['target']
## NFEAT indicadas para hacer DIM-REDUCTION
NFEAT = 40

# %%
## Calculamos SVD de nuestra BBDD.
U, s, VT = svd(data)

# %%
# Plot de los Autovalores
plt.yscale("log")
plt.plot((s*s))

# %%
# FUENTE: https://en.wikipedia.org/wiki/Principal_component_analysis#Compute_the_cumulative_energy_content_for_each_eigenvector
Total = sum(s)
for i in range(2, 51, 2):
    if (i == NFEAT):
        print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total" + " <--------- ELEGIDA ")
    else:
        print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total")
    
print("\n-------------Muchas Componentes-------------\n")
    
for i in range(100, 1000, 100):
    print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total")
# Out:
# Tomamos 2 componentes y nos queda un 12.31 % de la varianza total
# Tomamos 4 componentes y nos queda un 16.95 % de la varianza total
# Tomamos 6 componentes y nos queda un 20.38 % de la varianza total
# Tomamos 8 componentes y nos queda un 23.50 % de la varianza total
# Tomamos 10 componentes y nos queda un 26.03 % de la varianza total
# Tomamos 12 componentes y nos queda un 28.42 % de la varianza total
# Tomamos 14 componentes y nos queda un 30.63 % de la varianza total
# Tomamos 16 componentes y nos queda un 32.61 % de la varianza total
# Tomamos 18 componentes y nos queda un 34.44 % de la varianza total
# Tomamos 20 componentes y nos queda un 36.10 % de la varianza total
# Tomamos 22 componentes y nos queda un 37.65 % de la varianza total
# Tomamos 24 componentes y nos queda un 39.10 % de la varianza total
# Tomamos 26 componentes y nos queda un 40.48 % de la varianza total
# Tomamos 28 componentes y nos queda un 41.78 % de la varianza total
# Tomamos 30 componentes y nos queda un 43.02 % de la varianza total
# Tomamos 32 componentes y nos queda un 44.20 % de la varianza total
# Tomamos 34 componentes y nos queda un 45.34 % de la varianza total
# Tomamos 36 componentes y nos queda un 46.41 % de la varianza total
# Tomamos 38 componentes y nos queda un 47.46 % de la varianza total
# Tomamos 40 componentes y nos queda un 48.45 % de la varianza total <--------- ELEGIDA
# Tomamos 42 componentes y nos queda un 49.40 % de la varianza total
# Tomamos 44 componentes y nos queda un 50.32 % de la varianza total
# Tomamos 46 componentes y nos queda un 51.20 % de la varianza total
# Tomamos 48 componentes y nos queda un 52.05 % de la varianza total
# Tomamos 50 componentes y nos queda un 52.89 % de la varianza total
#
# -------------Muchas Componentes-------------
#
# Tomamos 100 componentes y nos queda un 67.74 % de la varianza total
# Tomamos 200 componentes y nos queda un 84.13 % de la varianza total
# Tomamos 300 componentes y nos queda un 93.49 % de la varianza total
# Tomamos 400 componentes y nos queda un 98.33 % de la varianza total
# Tomamos 500 componentes y nos queda un 99.93 % de la varianza total
# Tomamos 600 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 700 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 800 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 900 componentes y nos queda un 100.00 % de la varianza total

# %%
## Aplicamos PCA
start = timer()
pca = PCA(n_components=NFEAT)
reduced_data = pca.fit_transform(data)
recoverPCA = pca.inverse_transform(reduced_data)
recoverPCARS = np.array(recoverPCA).reshape(N, M, M, 1)
end = timer()
timePCA = (end - start) 
print("TimePCA --> %.3f" % (timePCA) + " s")

## Aplicamos NMF
start = timer()
model = NMF(n_components=NFEAT, init='random', random_state=0, max_iter=2000)
reduced_data = model.fit_transform(data)
recoverNMF = model.inverse_transform(reduced_data)
recoverNMFRS = np.array(recoverNMF).reshape(N, M, M, 1)
end = timer()
timeNMF = (end - start) 
print("TimeNMF --> %.3f" % (timeNMF) + " s")


## Aplicamos ICA
start = timer()
transformer = FastICA(n_components=40, random_state=0)
reduced_data = transformer.fit_transform(data)
recoverICA = transformer.inverse_transform(reduced_data)
recoverICARS = np.array(recoverICA).reshape(N, M, M, 1)
end = timer()
timeICA = (end - start) 
print("TimeICA --> %.3f" % (timeICA) + " s")
# Out:
# TimePCA --> 3.194 s
# TimeNMF --> 233.631 s
# TimeICA --> 9.378 s

# %%
errorPCA = mean_squared_error(data, recoverPCA)
print("MSE PCA --> %.3f" % (errorPCA))
errorNMF = mean_squared_error(data, recoverNMF)
print("MSE NMF --> %.3f" % (errorNMF))
errorICA = mean_squared_error(data, recoverICA)
print("MSE ICA --> %.3f" % (errorICA))
# Out:
# MSE PCA --> 716.199
# MSE NMF --> 978.005
# MSE ICA --> 716.131

# %% [markdown]
# ## Análisis por Clases (Solo PCA e ICA)

# %% [markdown]
# Solo vamos a utilizar PCA e ICA ya que hemos visto que NMF no es muy efectivo. Vamos a ver los MSE de cada número.

# %%
data = bnch['data']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)
unique, counts = np.unique(target, return_counts=True)
LL = {}
for i in range(10):
    L = np.ndarray((counts[i], M*M))
    k = 0
    j = 0
    for val in target:
        if (val == i):
            L[k][:] = data[j][:]
            k += 1
        j += 1
    L = L.reshape(counts[i], M, M)
    LL[str(i)] = L
    
    
for i in range(10):
    print("\n5 EJEMPLOS DE %d's\n" % i)
    for j in range(5):
        image = LL[str(i)][j]
        # plot the sample
        fig = plt.figure
        plt.imshow(image, cmap='gray_r')
        plt.show()
# Out:
# 5 EJEMPLOS DE 0's
# 5 EJEMPLOS DE 1's
# 5 EJEMPLOS DE 2's
# 5 EJEMPLOS DE 3's
# 5 EJEMPLOS DE 4's
# 5 EJEMPLOS DE 5's
# 5 EJEMPLOS DE 6's
# 5 EJEMPLOS DE 7's
# 5 EJEMPLOS DE 8's
# 5 EJEMPLOS DE 9's

# %%
table = [[],[],[],[],[],[]]
for i in range(10):
    table[0].append(i)
    data = LL[str(i)]
    data = data.reshape(counts[i], M*M)
    U, s, VT = svd(data)
    Total = sum(s)
    var = 100*(sum(s[:NFEAT])/Total)
    table[1].append("%.2f"% var + "%")
    
    start = timer()
    pca = PCA(n_components=NFEAT)
    reduced_data = pca.fit_transform(data)
    recoverPCA = pca.inverse_transform(reduced_data)
    errorPCA = mean_squared_error(data, recoverPCA)
    end = timer()
    
    errorPCA = mean_squared_error(data, recoverPCA)
    table[2].append(errorPCA)
    table[4].append("%.2f" % (end - start) + " s")
    
    start = timer()
    transformer = FastICA(n_components=NFEAT, random_state=0, max_iter = 1000)
    reduced_data = transformer.fit_transform(data)
    recoverICA = transformer.inverse_transform(reduced_data)
    end = timer()
    
    errorICA = mean_squared_error(data, recoverICA)
    table[3].append(errorICA)   
    table[5].append("%.2f" % (end - start) + " s")
# Out:
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_fastica.py:118: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '

# %%
table = zip(*table)  
print(tabulate(table, headers=["Numero", "Var (40 FEATS)", "ECM-PCA", "ECM-ICA", "TIME-PCA", "TIME-ICA"], tablefmt="grid"))
# Out:
# +----------+------------------+-----------+-----------+------------+------------+
# |   Numero | Var (40 FEATS)   |   ECM-PCA |   ECM-ICA | TIME-PCA   | TIME-ICA   |
# +==========+==================+===========+===========+============+============+
# |        0 | 47.77%           |   455.981 |   455.953 | 0.33 s     | 2.03 s     |
# +----------+------------------+-----------+-----------+------------+------------+
# |        1 | 54.41%           |   128.182 |   128.165 | 0.35 s     | 2.30 s     |
# +----------+------------------+-----------+-----------+------------+------------+
# |        2 | 43.46%           |   635.57  |   635.542 | 0.23 s     | 10.51 s    |
# +----------+------------------+-----------+-----------+------------+------------+
# |        3 | 44.21%           |   552.989 |   552.943 | 0.32 s     | 5.50 s     |
# +----------+------------------+-----------+-----------+------------+------------+
# |        4 | 44.64%           |   464.183 |   464.16  | 0.23 s     | 10.23 s    |
# +----------+------------------+-----------+-----------+------------+------------+
# |        5 | 44.10%           |   553.142 |   553.08  | 0.29 s     | 9.65 s     |
# +----------+------------------+-----------+-----------+------------+------------+
# |        6 | 47.97%           |   411.594 |   411.57  | 0.25 s     | 10.35 s    |
# +----------+------------------+-----------+-----------+------------+------------+
# |        7 | 46.35%           |   369.602 |   369.575 | 0.33 s     | 10.83 s    |
# +----------+------------------+-----------+-----------+------------+------------+
# |        8 | 44.65%           |   598.549 |   598.508 | 0.23 s     | 10.39 s    |
# +----------+------------------+-----------+-----------+------------+------------+
# |        9 | 48.45%           |   372.899 |   372.888 | 0.31 s     | 10.52 s    |
# +----------+------------------+-----------+-----------+------------+------------+
