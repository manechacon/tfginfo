# %%
# %load_ext autoreload
# %autoreload 2

# %%
import dimred_utils
import pickle
import matplotlib.pyplot as plt
import gzip
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Análisis en EOLO

# %%
# rng = RandomState(0)
nplot = 5
n_row, n_col = 1,5
image_shape = (32, 32)

f_pickle = "mnist_32.bnch"
f = gzip.open(f_pickle, mode='rb')
bnch = pickle.load(f)
f.close()
data = bnch['data_test']
# target = bnch['target_test']
N = data.shape[0]
M = data.shape[1]
data = np.array(data).reshape(N, M*M)

def plot_gallery(title, images, n_col=n_col, n_row=n_row, cmap=mpl.cm.Greys):
        plt.figure(figsize=(2. * n_col, 2.26 * n_row))
        plt.suptitle(title, size=16)
        for i, comp in enumerate(images):
            plt.subplot(n_row, n_col, i + 1)
            vmax = max(comp.max(), -comp.min())
            plt.imshow(comp.reshape(image_shape), cmap=cmap,
                       interpolation='nearest',
                       vmin=-vmax, vmax=vmax)
            plt.xticks(())
            plt.yticks(())
        plt.subplots_adjust(0.01, 0.05, 0.99, 0.93, 0.04, 0.)

# %%
dimred_utils.mnist_autoval_analisis(n_comp = 60)
# Out:
# Tomamos 60 componentes y nos queda un 90.37 % de la varianza total

# %%
dimred_utils.minist_pretest(n_comp = 60)
# Out:
# Extracting the top 60 PCA using randomized SVD...
# Error cuadrático medio en reconstrucción:  474.58404552911736
# done in 0.587s
#
#
#
# Extracting the top 60 Non-negative components - NMF...
# Error cuadrático medio en reconstrucción:  682.8160577251689
# done in 21.182s
#
#
#
# Extracting the top 60 Independent components - FastICA...
# Error cuadrático medio en reconstrucción:  474.4594163278157
# done in 9.328s

# %%
file_to_read = open("stored_objs/store_lin_60.pickle", "rb")
lin_ae = pickle.load(file_to_read)
file_to_read.close()

plt.plot(lin_ae.regressor_.named_steps['mlp_lin'].loss_curve_)
plt.yscale('log')

print(f'Error Cuadrático Medio del autoencoder lineal: {mean_squared_error(data, lin_ae.predict(data))}')
# Out:
# Error Cuadrático Medio del autoencoder lineal: 878.7442125150334

# %%
file_to_read = open("stored_objs/store_mul_60.pickle", "rb")
mul_ae = pickle.load(file_to_read)
file_to_read.close()

plt.plot(mul_ae.regressor_.named_steps['mlp_multi'].loss_curve_)
plt.yscale('log')

print(f'Error Cuadrático Medio del autoencoder multicapa: {mean_squared_error(data, mul_ae.predict(data))}')
# Out:
# Error Cuadrático Medio del autoencoder multicapa: 365.7517668531879

# %%
recover_lin = lin_ae.predict(data)
recover_multi = mul_ae.predict(data)

plot_gallery(f"First {nplot} images", data[:nplot])
plot_gallery('Recover-linear-ae', recover_lin[:nplot])
plot_gallery('Recover-multilayer-ae', recover_multi[:nplot])

# %%
print(data.mean(), data.var())
# Out:
# 25.87140625 5004.0478929443325

# %%
# %%html
# <style>
# .output_wrapper, .output {
#        height:auto !important;
#        max-height:10000px;  /* your desired max-height here */
# }
# .output_scroll {
#        box-shadow:none !important;
#        webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#        height:auto !important;
#        max-height:10000px;  /* your desired max-height here */
# }
# .output_scroll {
#        box-shadow:none !important;
#        webkit-box-shadow:none !important;
# }
# </style>
