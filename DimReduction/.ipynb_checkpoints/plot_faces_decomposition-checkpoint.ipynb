# %%
# %matplotlib inline

# %% [markdown]
# # Faces dataset decompositions
#
#
# This example applies to `olivetti_faces_dataset` different unsupervised
# matrix decomposition (dimension reduction) methods from the module
# :py:mod:`sklearn.decomposition` (see the documentation chapter
# `decompositions`) .

# %%
print(__doc__)

# Authors: Vlad Niculae, Alexandre Gramfort
# License: BSD 3 clause

import logging
from time import time

from numpy.random import RandomState
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_olivetti_faces
from sklearn.cluster import MiniBatchKMeans
from sklearn import decomposition

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')
n_row, n_col = 2, 3
n_components = n_row * n_col
image_shape = (64, 64)
rng = RandomState(0)

# #############################################################################
# Load faces data
faces, _ = fetch_olivetti_faces(return_X_y=True, shuffle=True,
                                random_state=rng)
n_samples, n_features = faces.shape
print(faces.shape)

# global centering
faces_centered = faces - faces.mean(axis=0)

# local centering
faces_centered -= faces_centered.mean(axis=1).reshape(n_samples, -1)

print("Dataset consists of %d faces" % n_samples)


def plot_gallery(title, images, n_col=n_col, n_row=n_row, cmap=plt.cm.gray):
    plt.figure(figsize=(2. * n_col, 2.26 * n_row))
    plt.suptitle(title, size=16)
    for i, comp in enumerate(images):
        plt.subplot(n_row, n_col, i + 1)
        vmax = max(comp.max(), -comp.min())
        plt.imshow(comp.reshape(image_shape), cmap=cmap,
                   interpolation='nearest',
                   vmin=-vmax, vmax=vmax)
        plt.xticks(())
        plt.yticks(())
    plt.subplots_adjust(0.01, 0.05, 0.99, 0.93, 0.04, 0.)

# #############################################################################
# List of the different estimators, whether to center and transpose the
# problem, and whether the transformer uses the clustering API.
estimators = [
    ('Eigenfaces - PCA using randomized SVD',
     decomposition.PCA(n_components=n_components, svd_solver='randomized',
                       whiten=True),
     True),

    ('Non-negative components - NMF',
     decomposition.NMF(n_components=n_components, init='nndsvda', tol=5e-3),
     False),

    ('Independent components - FastICA',
     decomposition.FastICA(n_components=n_components, whiten=True),
     True),

    ('Sparse comp. - MiniBatchSparsePCA',
     decomposition.MiniBatchSparsePCA(n_components=n_components, alpha=0.8,
                                      n_iter=100, batch_size=3,
                                      random_state=rng),
     True),

    ('MiniBatchDictionaryLearning',
        decomposition.MiniBatchDictionaryLearning(n_components=15, alpha=0.1,
                                                  n_iter=50, batch_size=3,
                                                  random_state=rng),
     True),

    ('Cluster centers - MiniBatchKMeans',
        MiniBatchKMeans(n_clusters=n_components, tol=1e-3, batch_size=20,
                        max_iter=50, random_state=rng),
     True),

    ('Factor Analysis components - FA',
     decomposition.FactorAnalysis(n_components=n_components, max_iter=20),
     True),
]


# #############################################################################
# Plot a sample of the input data

plot_gallery("First centered Olivetti faces", faces_centered[:n_components])

# #############################################################################
# Do the estimation and plot it

for name, estimator, center in estimators:
    print("Extracting the top %d %s..." % (n_components, name))
    t0 = time()
    data = faces
    if center:
        data = faces_centered
    estimator.fit(data)
    train_time = (time() - t0)
    print("done in %0.3fs" % train_time)
    if hasattr(estimator, 'cluster_centers_'):
        components_ = estimator.cluster_centers_
    else:
        components_ = estimator.components_

    # Plot an image representing the pixelwise variance provided by the
    # estimator e.g its noise_variance_ attribute. The Eigenfaces estimator,
    # via the PCA decomposition, also provides a scalar noise_variance_
    # (the mean of pixelwise variance) that cannot be displayed as an image
    # so we skip it.
    if (hasattr(estimator, 'noise_variance_') and
            estimator.noise_variance_.ndim > 0):  # Skip the Eigenfaces case
        plot_gallery("Pixelwise variance",
                     estimator.noise_variance_.reshape(1, -1), n_col=1,
                     n_row=1)
    plot_gallery('%s - Train time %.1fs' % (name, train_time),
                 components_[:n_components])

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# (400, 4096)
# Dataset consists of 400 faces
# Extracting the top 6 Eigenfaces - PCA using randomized SVD...
# done in 0.082s
# Extracting the top 6 Non-negative components - NMF...
# done in 0.092s
# Extracting the top 6 Independent components - FastICA...
# done in 0.124s
# Extracting the top 6 Sparse comp. - MiniBatchSparsePCA...
# done in 1.340s
# Extracting the top 6 MiniBatchDictionaryLearning...
# done in 1.163s
# Extracting the top 6 Cluster centers - MiniBatchKMeans...
# done in 0.216s
# Extracting the top 6 Factor Analysis components - FA...
# done in 0.248s

# %% [markdown]
# # Análisis Identico al de MNIST

# %%
import gzip
import pickle
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.decomposition import NMF
from sklearn.decomposition import FastICA
from sklearn.metrics import mean_squared_error
import numpy as np
from scipy.linalg import svd
from tabulate import tabulate

from timeit import default_timer as timer

# %%
data = faces
NFEAT = 6
N, M = data.shape
M = 64

# %%
## Calculamos SVD de nuestra BBDD.
U, s, VT = svd(data)

# %%
# Plot de los Autovalores
plt.yscale("log")
plt.plot((s*s))

# %%
# FUENTE: https://en.wikipedia.org/wiki/Principal_component_analysis#Compute_the_cumulative_energy_content_for_each_eigenvector
Total = sum(s)
for i in range(2, 51, 2):
    if (i == NFEAT):
        print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total" + " <--------- ELEGIDA ")
    else:
        print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total")
    
print("\n-------------Muchas Componentes-------------\n")
    
for i in range(100, 4000, 100):
    print("Tomamos %d componentes" % (i) + " y nos queda un %2.2f" % (100*(sum(s[:i])/Total)) +  " % de la varianza total")
# Out:
# Tomamos 2 componentes y nos queda un 30.46 % de la varianza total
# Tomamos 4 componentes y nos queda un 33.98 % de la varianza total
# Tomamos 6 componentes y nos queda un 36.61 % de la varianza total <--------- ELEGIDA
# Tomamos 8 componentes y nos queda un 38.72 % de la varianza total
# Tomamos 10 componentes y nos queda un 40.59 % de la varianza total
# Tomamos 12 componentes y nos queda un 42.29 % de la varianza total
# Tomamos 14 componentes y nos queda un 43.83 % de la varianza total
# Tomamos 16 componentes y nos queda un 45.23 % de la varianza total
# Tomamos 18 componentes y nos queda un 46.55 % de la varianza total
# Tomamos 20 componentes y nos queda un 47.74 % de la varianza total
# Tomamos 22 componentes y nos queda un 48.87 % de la varianza total
# Tomamos 24 componentes y nos queda un 49.93 % de la varianza total
# Tomamos 26 componentes y nos queda un 50.94 % de la varianza total
# Tomamos 28 componentes y nos queda un 51.92 % de la varianza total
# Tomamos 30 componentes y nos queda un 52.85 % de la varianza total
# Tomamos 32 componentes y nos queda un 53.72 % de la varianza total
# Tomamos 34 componentes y nos queda un 54.54 % de la varianza total
# Tomamos 36 componentes y nos queda un 55.33 % de la varianza total
# Tomamos 38 componentes y nos queda un 56.09 % de la varianza total
# Tomamos 40 componentes y nos queda un 56.82 % de la varianza total
# Tomamos 42 componentes y nos queda un 57.52 % de la varianza total
# Tomamos 44 componentes y nos queda un 58.20 % de la varianza total
# Tomamos 46 componentes y nos queda un 58.87 % de la varianza total
# Tomamos 48 componentes y nos queda un 59.52 % de la varianza total
# Tomamos 50 componentes y nos queda un 60.15 % de la varianza total
#
# -------------Muchas Componentes-------------
#
# Tomamos 100 componentes y nos queda un 72.18 % de la varianza total
# Tomamos 200 componentes y nos queda un 86.43 % de la varianza total
# Tomamos 300 componentes y nos queda un 94.96 % de la varianza total
# Tomamos 400 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 500 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 600 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 700 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 800 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 900 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1000 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1100 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1200 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1300 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1400 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1500 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1600 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1700 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1800 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 1900 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2000 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2100 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2200 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2300 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2400 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2500 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2600 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2700 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2800 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 2900 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3000 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3100 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3200 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3300 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3400 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3500 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3600 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3700 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3800 componentes y nos queda un 100.00 % de la varianza total
# Tomamos 3900 componentes y nos queda un 100.00 % de la varianza total

# %%
## Aplicamos PCA
start = timer()
pca = PCA(n_components=NFEAT, svd_solver='randomized',
                       whiten=True)
reduced_data = pca.fit_transform(data)
recoverPCA = pca.inverse_transform(reduced_data)
recoverPCARS = np.array(recoverPCA).reshape(N, M, M, 1)
end = timer()
timePCA = (end - start) 
print("TimePCA --> %.3f" % (timePCA) + " s")

## Aplicamos NMF
start = timer()
model = NMF(n_components=NFEAT, init='random', random_state=0, max_iter=2000)
reduced_data = model.fit_transform(data)
recoverNMF = model.inverse_transform(reduced_data)
recoverNMFRS = np.array(recoverNMF).reshape(N, M, M, 1)
end = timer()
timeNMF = (end - start) 
print("TimeNMF --> %.3f" % (timeNMF) + " s")


## Aplicamos ICA
start = timer()
transformer = FastICA(n_components=40, random_state=0)
reduced_data = transformer.fit_transform(data)
recoverICA = transformer.inverse_transform(reduced_data)
recoverICARS = np.array(recoverICA).reshape(N, M, M, 1)
end = timer()
timeICA = (end - start) 
print("TimeICA --> %.3f" % (timeICA) + " s")
# Out:
# TimePCA --> 0.095 s
# /home/josem.chacon/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 2000 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# TimeNMF --> 1.944 s
# TimeICA --> 0.237 s

# %%
errorPCA = mean_squared_error(data, recoverPCA)
print("MSE PCA --> %.3f" % (errorPCA))
errorNMF = mean_squared_error(data, recoverNMF)
print("MSE NMF --> %.3f" % (errorNMF))
errorICA = mean_squared_error(data, recoverICA)
print("MSE ICA --> %.3f" % (errorICA))
# Out:
# MSE PCA --> 0.008
# MSE NMF --> 0.008
# MSE ICA --> 0.003

# %% [markdown]
# Principal axes in feature space, representing the directions of maximum variance in the data. The components are sorted by explained_variance_.

# %%
if hasattr(pca, 'cluster_centers_'):
    components_ = pca.cluster_centers_
else:
    components_ = pca.components_
print(components_.shape)
print(pca.explained_variance_,sum(pca.explained_variance_))
for comp in components_:
    comp = comp.reshape(M, M)
    fig = plt.figure
    plt.imshow(comp, cmap=plt.cm.gray)
    plt.show()
# Out:
# (6, 4096)
# [18.84016   11.071765   6.3046155  3.9545858  2.8560438  2.4977074] 45.52487778663635

# %%
for i in range (6):
    image = recoverPCARS[i]
    fig = plt.figure
    plt.imshow(image, cmap=plt.cm.gray)
    plt.show()

# %%
for i in range (6):
    image = recoverNMFRS[i]
    fig = plt.figure
    plt.imshow(image, cmap=plt.cm.gray)
    plt.show()

# %%
for i in range (6):
    image = recoverICARS[i]
    fig = plt.figure
    plt.imshow(image, cmap=plt.cm.gray)
    plt.show()

# %% [markdown]
# En esta DB ICA se comporta mucho mejor que PCA. NMF queda de nuevo descartada.
